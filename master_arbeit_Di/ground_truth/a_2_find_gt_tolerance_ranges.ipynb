# %% [markdown]
# # Find GT Tolerance Ranges
#
# This notebook is only for estimating narrow Ground Truth ranges (I/T/OH):
#
# 1. Run baseline Urc1.
# 2. Keep high-quality windows (for example, R2 > 0.95).
# 3. Use median coefficients.
# 4. Back-calculate recommended I/T/OH ranges from partial derivatives +- 5 mV (in total 10mV) error budget.

# %%
from master_arbeit_Di.ground_truth.a_2_find_gt_tolerance_ranges import run_range_estimation

# %%
# ===== Run: G6M2 =====
result_g6m2_low = run_range_estimation(
    dataset_path=r'..\\..\\explore_data\\G6M2.parquet',
    output_dir=r'explore_data\\output',
    i_ref=0.28,
    t_ref=57,
    oh_ref=10,
    voltage_error_mv=5.0,
    r2_min=0.95,
    rmse_max_mv=None,
    cond_max=None,
)
# Out:
# === 1. Loading & Preprocessing: G6M2 ===
# >> Data loaded successfully.
#    [Detected] Temperature Col: 'Temp_Module_12' -> ID: '2'
# >> Columns renamed to standard format.
# >> Columns filtered. Retained: ['currentDensity', 'temperature', 'voltage']
#
# === 3. Saving Preprocessd data in .parquet format ===
# >> ✅ Final Results saved successfully to:
#    explore_data\\output\G6M2_20260506_161707.parquet
#
# === GMpreprocess Pipeline Completed Successfully ===
# Data preprocessing ...
# Before preprocess: 1096020 data points.
# After preprocess: 359353 data points.
#  (Filter criteria: i>0.1A/cm2, 1.4V<U<2.3V, 50degC<T<65degC, h_since_last_start>0.5h.)
#
# Voltage model fitting ...
# Fitting Stats: 218 intervals low data, 0 fit failed.
# 468 out of 762 fitting results are reliable.
# ...
# GT Narrow Range Estimation
# ...
# Dataset             : ..\\..\\explore_data\\G6M2.parquet
# Intervals total     : 762
# Intervals selected  : 488 (R2 >= 0.95)
# ...

# %%
# ===== Run: G6M2 =====
result_g6m2_medium = run_range_estimation(
    dataset_path=r'..\\..\\explore_data\\G6M2.parquet',
    output_dir=r'explore_data\\output',
    i_ref=1.0,
    t_ref=58,
    oh_ref=33,
    voltage_error_mv=5.0,
    r2_min=0.95,
    rmse_max_mv=None,
    cond_max=None,
)
# Out:
# === 1. Loading & Preprocessing: G6M2 ===
# >> Data loaded successfully.
#    [Detected] Temperature Col: 'Temp_Module_12' -> ID: '2'
# >> Columns renamed to standard format.
# >> Columns filtered. Retained: ['currentDensity', 'temperature', 'voltage']
#
# === 3. Saving Preprocessd data in .parquet format ===
# >> ✅ Final Results saved successfully to:
#    explore_data\\output\G6M2_20260506_161726.parquet
#
# === GMpreprocess Pipeline Completed Successfully ===
# Data preprocessing ...
# Before preprocess: 1096020 data points.
# After preprocess: 359353 data points.
#  (Filter criteria: i>0.1A/cm2, 1.4V<U<2.3V, 50degC<T<65degC, h_since_last_start>0.5h.)
#
# Voltage model fitting ...
# Fitting Stats: 218 intervals low data, 0 fit failed.
# 468 out of 762 fitting results are reliable.
# ...
# GT Narrow Range Estimation
# ...
# Dataset             : ..\\..\\explore_data\\G6M2.parquet
# Intervals total     : 762
# Intervals selected  : 488 (R2 >= 0.95)
# ...

# %%
# ===== Run: G6M2 =====
result_g6m2_high = run_range_estimation(
    dataset_path=r'..\\..\\explore_data\\G6M2.parquet',
    output_dir=r'explore_data\\output',
    i_ref=1.31,
    t_ref=58,
    oh_ref=18,
    voltage_error_mv=5.0,
    r2_min=0.95,
    rmse_max_mv=None,
    cond_max=None,
)
# Out:
# === 1. Loading & Preprocessing: G6M2 ===
# >> Data loaded successfully.
#    [Detected] Temperature Col: 'Temp_Module_12' -> ID: '2'
# >> Columns renamed to standard format.
# >> Columns filtered. Retained: ['currentDensity', 'temperature', 'voltage']
#
# === 3. Saving Preprocessd data in .parquet format ===
# >> ✅ Final Results saved successfully to:
#    explore_data\\output\G6M2_20260506_161744.parquet
#
# === GMpreprocess Pipeline Completed Successfully ===
# Data preprocessing ...
# Before preprocess: 1096020 data points.
# After preprocess: 359353 data points.
#  (Filter criteria: i>0.1A/cm2, 1.4V<U<2.3V, 50degC<T<65degC, h_since_last_start>0.5h.)
#
# Voltage model fitting ...
# Fitting Stats: 218 intervals low data, 0 fit failed.
# 468 out of 762 fitting results are reliable.
# ...
# GT Narrow Range Estimation
# ...
# Dataset             : ..\\..\\explore_data\\G6M2.parquet
# Intervals total     : 762
# Intervals selected  : 488 (R2 >= 0.95)
# ...

# %%
# ===== Run: G1M1 =====
result_g1m1_low = run_range_estimation(
    dataset_path=r'..\\..\\explore_data\\G1M1_new.parquet',
    output_dir=r'explore_data\\output',
    i_ref=0.3,
    t_ref=58,
    oh_ref=11,
    voltage_error_mv=5.0,
    r2_min=0.95,
    rmse_max_mv=None,
    cond_max=None,
)
# Out:
# === 1. Loading & Preprocessing: G1M1_new ===
# >> Data loaded successfully.
#    [Detected] Temperature Col: 'Temp_Module_1' -> ID: '1'
# >> Columns renamed to standard format.
# >> Columns filtered. Retained: ['currentDensity', 'temperature', 'voltage']
#
# === 3. Saving Preprocessd data in .parquet format ===
# >> ✅ Final Results saved successfully to:
#    explore_data\\output\G1M1_new_20260506_161803.parquet
#
# === GMpreprocess Pipeline Completed Successfully ===
# Data preprocessing ...
# Before preprocess: 2529217 data points.
# After preprocess: 1069062 data points.
#  (Filter criteria: i>0.1A/cm2, 1.4V<U<2.3V, 50degC<T<65degC, h_since_last_start>0.5h.)
#
# Voltage model fitting ...
# Fitting Stats: 474 intervals low data, 0 fit failed.
# 1098 out of 1766 fitting results are reliable.
# ...
# GT Narrow Range Estimation
# ...
# Dataset             : ..\\..\\explore_data\\G1M1_new.parquet
# Intervals total     : 1766
# Intervals selected  : 1160 (R2 >= 0.95)
# ...

# %%
# ===== Run: G1M1 =====
result_g1m1_medium = run_range_estimation(
    dataset_path=r'..\\..\\explore_data\\G1M1_new.parquet',
    output_dir=r'explore_data\\output',
    i_ref=1.0,
    t_ref=58,
    oh_ref=100,
    voltage_error_mv=5.0,
    r2_min=0.95,
    rmse_max_mv=None,
    cond_max=None,
)
# Out:
# === 1. Loading & Preprocessing: G1M1_new ===
# >> Data loaded successfully.
#    [Detected] Temperature Col: 'Temp_Module_1' -> ID: '1'
# >> Columns renamed to standard format.
# >> Columns filtered. Retained: ['currentDensity', 'temperature', 'voltage']
#
# === 3. Saving Preprocessd data in .parquet format ===
# >> ✅ Final Results saved successfully to:
#    explore_data\\output\G1M1_new_20260506_161911.parquet
#
# === GMpreprocess Pipeline Completed Successfully ===
# Data preprocessing ...
# Before preprocess: 2529217 data points.
# After preprocess: 1069062 data points.
#  (Filter criteria: i>0.1A/cm2, 1.4V<U<2.3V, 50degC<T<65degC, h_since_last_start>0.5h.)
#
# Voltage model fitting ...
# Fitting Stats: 474 intervals low data, 0 fit failed.
# 1098 out of 1766 fitting results are reliable.
# ...
# GT Narrow Range Estimation
# ...
# Dataset             : ..\\..\\explore_data\\G1M1_new.parquet
# Intervals total     : 1766
# Intervals selected  : 1160 (R2 >= 0.95)
# ...

# %%
# ===== Run: G1M1 =====
result_g1m1_high = run_range_estimation(
    dataset_path=r'..\\..\\explore_data\\G1M1_new.parquet',
    output_dir=r'explore_data\\output',
    i_ref=1.48,
    t_ref=57,
    oh_ref=100,
    voltage_error_mv=5.0,
    r2_min=0.95,
    rmse_max_mv=None,
    cond_max=None,
)
# Out:
# === 1. Loading & Preprocessing: G1M1_new ===
# >> Data loaded successfully.
#    [Detected] Temperature Col: 'Temp_Module_1' -> ID: '1'
# >> Columns renamed to standard format.
# >> Columns filtered. Retained: ['currentDensity', 'temperature', 'voltage']
#
# === 3. Saving Preprocessd data in .parquet format ===
# >> ✅ Final Results saved successfully to:
#    explore_data\\output\G1M1_new_20260506_162027.parquet
#
# === GMpreprocess Pipeline Completed Successfully ===
# Data preprocessing ...
# Before preprocess: 2529217 data points.
# After preprocess: 1069062 data points.
#  (Filter criteria: i>0.1A/cm2, 1.4V<U<2.3V, 50degC<T<65degC, h_since_last_start>0.5h.)
#
# Voltage model fitting ...
# Fitting Stats: 474 intervals low data, 0 fit failed.
# 1099 out of 1766 fitting results are reliable.
# ...
# GT Narrow Range Estimation
# ...
# Dataset             : ..\\..\\explore_data\\G1M1_new.parquet
# Intervals total     : 1766
# Intervals selected  : 1160 (R2 >= 0.95)
# ...
